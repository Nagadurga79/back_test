# %%
# import data
import pandas as pd
df=pd.read_csv(r"E:\durga79\PROJECTS\BACT_TEST_PROJECT\BACK_TEST_CSV")
df
# Out:
#     orginal_frequency  predicted_frequency  original_cost  predicted_cost
# 0                   5                    5           1000            1000
# 1                   6                    5           1500            1200
# 2                   7                    6           2000            1300
# 3                   8                    8           2500            2500
# 4                   9                    8           1000            1000
# 5                   7                    7           2000            2000
# 6                   8                    7           2500            2500
# 7                   5                    5           3000            3000
# 8                   4                    4           4000            4000
# 9                   8                    8           1500            1500
# 10                  9                    8           1800            1800
# 11                  5                    5           1200            1200
# ...

# %%
# basic checks
df.head()
# Out:
#    orginal_frequency  predicted_frequency  original_cost  predicted_cost
# 0                  5                    5           1000            1000
# 1                  6                    5           1500            1200
# 2                  7                    6           2000            1300
# 3                  8                    8           2500            2500
# 4                  9                    8           1000            1000

# %%
df.tail()
# Out:
#     orginal_frequency  predicted_frequency  original_cost  predicted_cost
# 9                   8                    8           1500            1500
# 10                  9                    8           1800            1800
# 11                  5                    5           1200            1200
# 12                  4                    4           1300            1300
# 13                  3                    3           1500            1500

# %%
df.columns
# Out:
# Index(['orginal_frequency', 'predicted_frequency', 'original_cost',
#        'predicted_cost'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   orginal_frequency    14 non-null     int64
#  1   predicted_frequency  14 non-null     int64
#  2   original_cost        14 non-null     int64
#  3   predicted_cost       14 non-null     int64
# dtypes: int64(4)
# memory usage: 576.0 bytes

# %%
# 1.back test_frequency_delta_percentage
df["bt_fre_delta_pct"]=((df["predicted_frequency"]-df["orginal_frequency"])/df["orginal_frequency"])*100

# %%
df
# Out:
#     orginal_frequency  predicted_frequency  original_cost  predicted_cost  \
# 0                   5                    5           1000            1000
# 1                   6                    5           1500            1200
# 2                   7                    6           2000            1300
# 3                   8                    8           2500            2500
# 4                   9                    8           1000            1000
# 5                   7                    7           2000            2000
# 6                   8                    7           2500            2500
# 7                   5                    5           3000            3000
# 8                   4                    4           4000            4000
# 9                   8                    8           1500            1500
# 10                  9                    8           1800            1800
# 11                  5                    5           1200            1200
# ...

# %%
# 2.back testing cost delta percentage
df["bt_cost_delta_pct"]=((df["predicted_cost"]-df['original_cost'])/df['original_cost'])*100

# %%
df
# Out:
#     orginal_frequency  predicted_frequency  original_cost  predicted_cost  \
# 0                   5                    5           1000            1000
# 1                   6                    5           1500            1200
# 2                   7                    6           2000            1300
# 3                   8                    8           2500            2500
# 4                   9                    8           1000            1000
# 5                   7                    7           2000            2000
# 6                   8                    7           2500            2500
# 7                   5                    5           3000            3000
# 8                   4                    4           4000            4000
# 9                   8                    8           1500            1500
# 10                  9                    8           1800            1800
# 11                  5                    5           1200            1200
# ...

# %%
# 3.Frequency delta
df["Freq_delta"]=df["predicted_frequency"]-df["orginal_frequency"]

# %%
df
# Out:
#     orginal_frequency  predicted_frequency  original_cost  predicted_cost  \
# 0                   5                    5           1000            1000
# 1                   6                    5           1500            1200
# 2                   7                    6           2000            1300
# 3                   8                    8           2500            2500
# 4                   9                    8           1000            1000
# 5                   7                    7           2000            2000
# 6                   8                    7           2500            2500
# 7                   5                    5           3000            3000
# 8                   4                    4           4000            4000
# 9                   8                    8           1500            1500
# 10                  9                    8           1800            1800
# 11                  5                    5           1200            1200
# ...

# %%
# 4.cost delta
df["cost_delta"]=df["predicted_cost"]-df["original_cost"]

# %%
df
# Out:
#     orginal_frequency  predicted_frequency  original_cost  predicted_cost  \
# 0                   5                    5           1000            1000
# 1                   6                    5           1500            1200
# 2                   7                    6           2000            1300
# 3                   8                    8           2500            2500
# 4                   9                    8           1000            1000
# 5                   7                    7           2000            2000
# 6                   8                    7           2500            2500
# 7                   5                    5           3000            3000
# 8                   4                    4           4000            4000
# 9                   8                    8           1500            1500
# 10                  9                    8           1800            1800
# 11                  5                    5           1200            1200
# ...
